# %% [markdown]
# - NOTE!: HERE We ASSUME that the datasets contains already S21, NOT the output power. We keep track of input power in each the dataset name.

# %% [markdown]
# Libraries and functions found on web to display content of a .h5 file

# %%
import h5py
import numpy as np
from h5utils import *
import matplotlib.pyplot as plt
from matplotlib import cm
import sys

# %%
filename = "measure_exitation_9_06_VNA-20dBm_1MHzVNARange.h5";   # Change HERE!!!

# %% [markdown]
# Here you can see the content of the file

# %%
"""PRINT ALL the .h5 file directories"""
h5dump(filename,group = "/");
# Out:
# 	 [ 0 ] - <HDF5 group "/" (1 members)>
# 		 [ 0 ] - <HDF5 group "/SMA_power-20dBm" (801 members)>
# 			 [ 0 ]- /SMA_power-20dBm/drive_freq0 : (3, 10)
# 			 [ 1 ]- /SMA_power-20dBm/drive_freq1 : (3, 10)
# 			 [ 2 ]- /SMA_power-20dBm/drive_freq10 : (3, 10)
# 			 [ 3 ]- /SMA_power-20dBm/drive_freq100 : (3, 10)
# 			 [ 4 ]- /SMA_power-20dBm/drive_freq101 : (3, 10)
# 			 [ 5 ]- /SMA_power-20dBm/drive_freq102 : (3, 10)
# 			 [ 6 ]- /SMA_power-20dBm/drive_freq103 : (3, 10)
# 			 [ 7 ]- /SMA_power-20dBm/drive_freq104 : (3, 10)
# 			 [ 8 ]- /SMA_power-20dBm/drive_freq105 : (3, 10)
# 			 [ 9 ]- /SMA_power-20dBm/drive_freq106 : (3, 10)
# 			 [ 10 ]- /SMA_power-20dBm/drive_freq107 : (3, 10)
# 			 [ 11 ]- /SMA_power-20dBm/drive_freq108 : (3, 10)
# 			 [ 12 ]- /SMA_power-20dBm/drive_freq109 : (3, 10)
# 			 [ 13 ]- /SMA_power-20dBm/drive_freq11 : (3, 10)
# 			 [ 14 ]- /SMA_power-20dBm/drive_freq110 : (3, 10)
# 			 [ 15 ]- /SMA_power-20dBm/drive_freq111 : (3, 10)
# 			 [ 16 ]- /SMA_power-20dBm/drive_freq112 : (3, 10)
# 			 [ 17 ]- /SMA_power-20dBm/drive_freq113 : (3, 10)
# 			 [ 18 ]- /SMA_power-20dBm/drive_freq114 : (3, 10)
# 			 [ 19 ]- /SMA_power-20dBm/drive_freq115 : (3, 10)
# 			 [ 20 ]- /SMA_power-20dBm/drive_freq116 : (3, 10)
# 			 [ 21 ]- /SMA_power-20dBm/drive_freq117 : (3, 10)
# 			 [ 22 ]- /SMA_power-20dBm/drive_freq118 : (3, 10)
# 			 [ 23 ]- /SMA_power-20dBm/drive_freq119 : (3, 10)
# 			 [ 24 ]- /SMA_power-20dBm/drive_freq12 : (3, 10)
# 			 [ 25 ]- /SMA_power-20dBm/drive_freq120 : (3, 10)
# 			 [ 26 ]- /SMA_power-20dBm/drive_freq121 : (3, 10)
# 			 [ 27 ]- /SMA_power-20dBm/drive_freq122 : (3, 10)
# 			 [ 28 ]- /SMA_power-20dBm/drive_freq123 : (3, 10)
# 			 [ 29 ]- /SMA_power-20dBm/drive_freq124 : (3, 10)
# 			 [ 30 ]- /SMA_power-20dBm/drive_freq125 : (3, 10)
# 			 [ 31 ]- /SMA_power-20dBm/drive_freq126 : (3, 10)
# 			 [ 32 ]- /SMA_power-20dBm/drive_freq127 : (3, 10)
# 			 [ 33 ]- /SMA_power-20dBm/drive_freq128 : (3, 10)
# 			 [ 34 ]- /SMA_power-20dBm/drive_freq129 : (3, 10)
# 			 [ 35 ]- /SMA_power-20dBm/drive_freq13 : (3, 10)
# 			 [ 36 ]- /SMA_power-20dBm/drive_freq130 : (3, 10)
# 			 [ 37 ]- /SMA_power-20dBm/drive_freq131 : (3, 10)
# 			 [ 38 ]- /SMA_power-20dBm/drive_freq132 : (3, 10)
# 			 [ 39 ]- /SMA_power-20dBm/drive_freq133 : (3, 10)
# 			 [ 40 ]- /SMA_power-20dBm/drive_freq134 : (3, 10)
# 			 [ 41 ]- /SMA_power-20dBm/drive_freq135 : (3, 10)
# 			 [ 42 ]- /SMA_power-20dBm/drive_freq136 : (3, 10)
# 			 [ 43 ]- /SMA_power-20dBm/drive_freq137 : (3, 10)
# 			 [ 44 ]- /SMA_power-20dBm/drive_freq138 : (3, 10)
# 			 [ 45 ]- /SMA_power-20dBm/drive_freq139 : (3, 10)
# 			 [ 46 ]- /SMA_power-20dBm/drive_freq14 : (3, 10)
# 			 [ 47 ]- /SMA_power-20dBm/drive_freq140 : (3, 10)
# 			 [ 48 ]- /SMA_power-20dBm/drive_freq141 : (3, 10)
# 			 [ 49 ]- /SMA_power-20dBm/drive_freq142 : (3, 10)
# 			 [ 50 ]- /SMA_power-20dBm/drive_freq143 : (3, 10)
# 			 [ 51 ]- /SMA_power-20dBm/drive_freq144 : (3, 10)
# 			 [ 52 ]- /SMA_power-20dBm/drive_freq145 : (3, 10)
# 			 [ 53 ]- /SMA_power-20dBm/drive_freq146 : (3, 10)
# 			 [ 54 ]- /SMA_power-20dBm/drive_freq147 : (3, 10)
# 			 [ 55 ]- /SMA_power-20dBm/drive_freq148 : (3, 10)
# 			 [ 56 ]- /SMA_power-20dBm/drive_freq149 : (3, 10)
# 			 [ 57 ]- /SMA_power-20dBm/drive_freq15 : (3, 10)
# 			 [ 58 ]- /SMA_power-20dBm/drive_freq150 : (3, 10)
# 			 [ 59 ]- /SMA_power-20dBm/drive_freq151 : (3, 10)
# 			 [ 60 ]- /SMA_power-20dBm/drive_freq152 : (3, 10)
# 			 [ 61 ]- /SMA_power-20dBm/drive_freq153 : (3, 10)
# 			 [ 62 ]- /SMA_power-20dBm/drive_freq154 : (3, 10)
# 			 [ 63 ]- /SMA_power-20dBm/drive_freq155 : (3, 10)
# 			 [ 64 ]- /SMA_power-20dBm/drive_freq156 : (3, 10)
# 			 [ 65 ]- /SMA_power-20dBm/drive_freq157 : (3, 10)
# 			 [ 66 ]- /SMA_power-20dBm/drive_freq158 : (3, 10)
# 			 [ 67 ]- /SMA_power-20dBm/drive_freq159 : (3, 10)
# 			 [ 68 ]- /SMA_power-20dBm/drive_freq16 : (3, 10)
# 			 [ 69 ]- /SMA_power-20dBm/drive_freq160 : (3, 10)
# 			 [ 70 ]- /SMA_power-20dBm/drive_freq161 : (3, 10)
# 			 [ 71 ]- /SMA_power-20dBm/drive_freq162 : (3, 10)
# 			 [ 72 ]- /SMA_power-20dBm/drive_freq163 : (3, 10)
# 			 [ 73 ]- /SMA_power-20dBm/drive_freq164 : (3, 10)
# 			 [ 74 ]- /SMA_power-20dBm/drive_freq165 : (3, 10)
# 			 [ 75 ]- /SMA_power-20dBm/drive_freq166 : (3, 10)
# 			 [ 76 ]- /SMA_power-20dBm/drive_freq167 : (3, 10)
# 			 [ 77 ]- /SMA_power-20dBm/drive_freq168 : (3, 10)
# 			 [ 78 ]- /SMA_power-20dBm/drive_freq169 : (3, 10)
# 			 [ 79 ]- /SMA_power-20dBm/drive_freq17 : (3, 10)
# 			 [ 80 ]- /SMA_power-20dBm/drive_freq170 : (3, 10)
# 			 [ 81 ]- /SMA_power-20dBm/drive_freq171 : (3, 10)
# 			 [ 82 ]- /SMA_power-20dBm/drive_freq172 : (3, 10)
# 			 [ 83 ]- /SMA_power-20dBm/drive_freq173 : (3, 10)
# 			 [ 84 ]- /SMA_power-20dBm/drive_freq174 : (3, 10)
# 			 [ 85 ]- /SMA_power-20dBm/drive_freq175 : (3, 10)
# 			 [ 86 ]- /SMA_power-20dBm/drive_freq176 : (3, 10)
# 			 [ 87 ]- /SMA_power-20dBm/drive_freq177 : (3, 10)
# 			 [ 88 ]- /SMA_power-20dBm/drive_freq178 : (3, 10)
# 			 [ 89 ]- /SMA_power-20dBm/drive_freq179 : (3, 10)
# 			 [ 90 ]- /SMA_power-20dBm/drive_freq18 : (3, 10)
# 			 [ 91 ]- /SMA_power-20dBm/drive_freq180 : (3, 10)
# 			 [ 92 ]- /SMA_power-20dBm/drive_freq181 : (3, 10)
# 			 [ 93 ]- /SMA_power-20dBm/drive_freq182 : (3, 10)
# 			 [ 94 ]- /SMA_power-20dBm/drive_freq183 : (3, 10)
# 			 [ 95 ]- /SMA_power-20dBm/drive_freq184 : (3, 10)
# 			 [ 96 ]- /SMA_power-20dBm/drive_freq185 : (3, 10)
# 			 [ 97 ]- /SMA_power-20dBm/drive_freq186 : (3, 10)
# 			 [ 98 ]- /SMA_power-20dBm/drive_freq187 : (3, 10)
# 			 [ 99 ]- /SMA_power-20dBm/drive_freq188 : (3, 10)
# 			 [ 100 ]- /SMA_power-20dBm/drive_freq189 : (3, 10)
# 			 [ 101 ]- /SMA_power-20dBm/drive_freq19 : (3, 10)
# 			 [ 102 ]- /SMA_power-20dBm/drive_freq190 : (3, 10)
# 			 [ 103 ]- /SMA_power-20dBm/drive_freq191 : (3, 10)
# 			 [ 104 ]- /SMA_power-20dBm/drive_freq192 : (3, 10)
# 			 [ 105 ]- /SMA_power-20dBm/drive_freq193 : (3, 10)
# 			 [ 106 ]- /SMA_power-20dBm/drive_freq194 : (3, 10)
# 			 [ 107 ]- /SMA_power-20dBm/drive_freq195 : (3, 10)
# 			 [ 108 ]- /SMA_power-20dBm/drive_freq196 : (3, 10)
# 			 [ 109 ]- /SMA_power-20dBm/drive_freq197 : (3, 10)
# 			 [ 110 ]- /SMA_power-20dBm/drive_freq198 : (3, 10)
# 			 [ 111 ]- /SMA_power-20dBm/drive_freq199 : (3, 10)
# 			 [ 112 ]- /SMA_power-20dBm/drive_freq2 : (3, 10)
# 			 [ 113 ]- /SMA_power-20dBm/drive_freq20 : (3, 10)
# 			 [ 114 ]- /SMA_power-20dBm/drive_freq200 : (3, 10)
# 			 [ 115 ]- /SMA_power-20dBm/drive_freq201 : (3, 10)
# 			 [ 116 ]- /SMA_power-20dBm/drive_freq202 : (3, 10)
# 			 [ 117 ]- /SMA_power-20dBm/drive_freq203 : (3, 10)
# 			 [ 118 ]- /SMA_power-20dBm/drive_freq204 : (3, 10)
# 			 [ 119 ]- /SMA_power-20dBm/drive_freq205 : (3, 10)
# 			 [ 120 ]- /SMA_power-20dBm/drive_freq206 : (3, 10)
# 			 [ 121 ]- /SMA_power-20dBm/drive_freq207 : (3, 10)
# 			 [ 122 ]- /SMA_power-20dBm/drive_freq208 : (3, 10)
# 			 [ 123 ]- /SMA_power-20dBm/drive_freq209 : (3, 10)
# 			 [ 124 ]- /SMA_power-20dBm/drive_freq21 : (3, 10)
# 			 [ 125 ]- /SMA_power-20dBm/drive_freq210 : (3, 10)
# 			 [ 126 ]- /SMA_power-20dBm/drive_freq211 : (3, 10)
# 			 [ 127 ]- /SMA_power-20dBm/drive_freq212 : (3, 10)
# 			 [ 128 ]- /SMA_power-20dBm/drive_freq213 : (3, 10)
# 			 [ 129 ]- /SMA_power-20dBm/drive_freq214 : (3, 10)
# 			 [ 130 ]- /SMA_power-20dBm/drive_freq215 : (3, 10)
# 			 [ 131 ]- /SMA_power-20dBm/drive_freq216 : (3, 10)
# 			 [ 132 ]- /SMA_power-20dBm/drive_freq217 : (3, 10)
# 			 [ 133 ]- /SMA_power-20dBm/drive_freq218 : (3, 10)
# 			 [ 134 ]- /SMA_power-20dBm/drive_freq219 : (3, 10)
# 			 [ 135 ]- /SMA_power-20dBm/drive_freq22 : (3, 10)
# 			 [ 136 ]- /SMA_power-20dBm/drive_freq220 : (3, 10)
# 			 [ 137 ]- /SMA_power-20dBm/drive_freq221 : (3, 10)
# 			 [ 138 ]- /SMA_power-20dBm/drive_freq222 : (3, 10)
# 			 [ 139 ]- /SMA_power-20dBm/drive_freq223 : (3, 10)
# 			 [ 140 ]- /SMA_power-20dBm/drive_freq224 : (3, 10)
# 			 [ 141 ]- /SMA_power-20dBm/drive_freq225 : (3, 10)
# 			 [ 142 ]- /SMA_power-20dBm/drive_freq226 : (3, 10)
# 			 [ 143 ]- /SMA_power-20dBm/drive_freq227 : (3, 10)
# 			 [ 144 ]- /SMA_power-20dBm/drive_freq228 : (3, 10)
# 			 [ 145 ]- /SMA_power-20dBm/drive_freq229 : (3, 10)
# 			 [ 146 ]- /SMA_power-20dBm/drive_freq23 : (3, 10)
# 			 [ 147 ]- /SMA_power-20dBm/drive_freq230 : (3, 10)
# 			 [ 148 ]- /SMA_power-20dBm/drive_freq231 : (3, 10)
# 			 [ 149 ]- /SMA_power-20dBm/drive_freq232 : (3, 10)
# 			 [ 150 ]- /SMA_power-20dBm/drive_freq233 : (3, 10)
# 			 [ 151 ]- /SMA_power-20dBm/drive_freq234 : (3, 10)
# 			 [ 152 ]- /SMA_power-20dBm/drive_freq235 : (3, 10)
# 			 [ 153 ]- /SMA_power-20dBm/drive_freq236 : (3, 10)
# 			 [ 154 ]- /SMA_power-20dBm/drive_freq237 : (3, 10)
# 			 [ 155 ]- /SMA_power-20dBm/drive_freq238 : (3, 10)
# 			 [ 156 ]- /SMA_power-20dBm/drive_freq239 : (3, 10)
# 			 [ 157 ]- /SMA_power-20dBm/drive_freq24 : (3, 10)
# 			 [ 158 ]- /SMA_power-20dBm/drive_freq240 : (3, 10)
# 			 [ 159 ]- /SMA_power-20dBm/drive_freq241 : (3, 10)
# 			 [ 160 ]- /SMA_power-20dBm/drive_freq242 : (3, 10)
# 			 [ 161 ]- /SMA_power-20dBm/drive_freq243 : (3, 10)
# 			 [ 162 ]- /SMA_power-20dBm/drive_freq244 : (3, 10)
# 			 [ 163 ]- /SMA_power-20dBm/drive_freq245 : (3, 10)
# 			 [ 164 ]- /SMA_power-20dBm/drive_freq246 : (3, 10)
# 			 [ 165 ]- /SMA_power-20dBm/drive_freq247 : (3, 10)
# 			 [ 166 ]- /SMA_power-20dBm/drive_freq248 : (3, 10)
# 			 [ 167 ]- /SMA_power-20dBm/drive_freq249 : (3, 10)
# 			 [ 168 ]- /SMA_power-20dBm/drive_freq25 : (3, 10)
# 			 [ 169 ]- /SMA_power-20dBm/drive_freq250 : (3, 10)
# 			 [ 170 ]- /SMA_power-20dBm/drive_freq251 : (3, 10)
# 			 [ 171 ]- /SMA_power-20dBm/drive_freq252 : (3, 10)
# 			 [ 172 ]- /SMA_power-20dBm/drive_freq253 : (3, 10)
# 			 [ 173 ]- /SMA_power-20dBm/drive_freq254 : (3, 10)
# 			 [ 174 ]- /SMA_power-20dBm/drive_freq255 : (3, 10)
# 			 [ 175 ]- /SMA_power-20dBm/drive_freq256 : (3, 10)
# 			 [ 176 ]- /SMA_power-20dBm/drive_freq257 : (3, 10)
# 			 [ 177 ]- /SMA_power-20dBm/drive_freq258 : (3, 10)
# 			 [ 178 ]- /SMA_power-20dBm/drive_freq259 : (3, 10)
# 			 [ 179 ]- /SMA_power-20dBm/drive_freq26 : (3, 10)
# 			 [ 180 ]- /SMA_power-20dBm/drive_freq260 : (3, 10)
# 			 [ 181 ]- /SMA_power-20dBm/drive_freq261 : (3, 10)
# 			 [ 182 ]- /SMA_power-20dBm/drive_freq262 : (3, 10)
# 			 [ 183 ]- /SMA_power-20dBm/drive_freq263 : (3, 10)
# 			 [ 184 ]- /SMA_power-20dBm/drive_freq264 : (3, 10)
# 			 [ 185 ]- /SMA_power-20dBm/drive_freq265 : (3, 10)
# 			 [ 186 ]- /SMA_power-20dBm/drive_freq266 : (3, 10)
# 			 [ 187 ]- /SMA_power-20dBm/drive_freq267 : (3, 10)
# 			 [ 188 ]- /SMA_power-20dBm/drive_freq268 : (3, 10)
# 			 [ 189 ]- /SMA_power-20dBm/drive_freq269 : (3, 10)
# 			 [ 190 ]- /SMA_power-20dBm/drive_freq27 : (3, 10)
# 			 [ 191 ]- /SMA_power-20dBm/drive_freq270 : (3, 10)
# 			 [ 192 ]- /SMA_power-20dBm/drive_freq271 : (3, 10)
# 			 [ 193 ]- /SMA_power-20dBm/drive_freq272 : (3, 10)
# 			 [ 194 ]- /SMA_power-20dBm/drive_freq273 : (3, 10)
# 			 [ 195 ]- /SMA_power-20dBm/drive_freq274 : (3, 10)
# 			 [ 196 ]- /SMA_power-20dBm/drive_freq275 : (3, 10)
# 			 [ 197 ]- /SMA_power-20dBm/drive_freq276 : (3, 10)
# 			 [ 198 ]- /SMA_power-20dBm/drive_freq277 : (3, 10)
# 			 [ 199 ]- /SMA_power-20dBm/drive_freq278 : (3, 10)
# 			 [ 200 ]- /SMA_power-20dBm/drive_freq279 : (3, 10)
# 			 [ 201 ]- /SMA_power-20dBm/drive_freq28 : (3, 10)
# 			 [ 202 ]- /SMA_power-20dBm/drive_freq280 : (3, 10)
# 			 [ 203 ]- /SMA_power-20dBm/drive_freq281 : (3, 10)
# 			 [ 204 ]- /SMA_power-20dBm/drive_freq282 : (3, 10)
# 			 [ 205 ]- /SMA_power-20dBm/drive_freq283 : (3, 10)
# 			 [ 206 ]- /SMA_power-20dBm/drive_freq284 : (3, 10)
# 			 [ 207 ]- /SMA_power-20dBm/drive_freq285 : (3, 10)
# 			 [ 208 ]- /SMA_power-20dBm/drive_freq286 : (3, 10)
# 			 [ 209 ]- /SMA_power-20dBm/drive_freq287 : (3, 10)
# 			 [ 210 ]- /SMA_power-20dBm/drive_freq288 : (3, 10)
# 			 [ 211 ]- /SMA_power-20dBm/drive_freq289 : (3, 10)
# 			 [ 212 ]- /SMA_power-20dBm/drive_freq29 : (3, 10)
# 			 [ 213 ]- /SMA_power-20dBm/drive_freq290 : (3, 10)
# 			 [ 214 ]- /SMA_power-20dBm/drive_freq291 : (3, 10)
# 			 [ 215 ]- /SMA_power-20dBm/drive_freq292 : (3, 10)
# 			 [ 216 ]- /SMA_power-20dBm/drive_freq293 : (3, 10)
# 			 [ 217 ]- /SMA_power-20dBm/drive_freq294 : (3, 10)
# 			 [ 218 ]- /SMA_power-20dBm/drive_freq295 : (3, 10)
# 			 [ 219 ]- /SMA_power-20dBm/drive_freq296 : (3, 10)
# 			 [ 220 ]- /SMA_power-20dBm/drive_freq297 : (3, 10)
# 			 [ 221 ]- /SMA_power-20dBm/drive_freq298 : (3, 10)
# 			 [ 222 ]- /SMA_power-20dBm/drive_freq299 : (3, 10)
# 			 [ 223 ]- /SMA_power-20dBm/drive_freq3 : (3, 10)
# 			 [ 224 ]- /SMA_power-20dBm/drive_freq30 : (3, 10)
# 			 [ 225 ]- /SMA_power-20dBm/drive_freq300 : (3, 10)
# 			 [ 226 ]- /SMA_power-20dBm/drive_freq301 : (3, 10)
# 			 [ 227 ]- /SMA_power-20dBm/drive_freq302 : (3, 10)
# 			 [ 228 ]- /SMA_power-20dBm/drive_freq303 : (3, 10)
# 			 [ 229 ]- /SMA_power-20dBm/drive_freq304 : (3, 10)
# 			 [ 230 ]- /SMA_power-20dBm/drive_freq305 : (3, 10)
# 			 [ 231 ]- /SMA_power-20dBm/drive_freq306 : (3, 10)
# 			 [ 232 ]- /SMA_power-20dBm/drive_freq307 : (3, 10)
# 			 [ 233 ]- /SMA_power-20dBm/drive_freq308 : (3, 10)
# 			 [ 234 ]- /SMA_power-20dBm/drive_freq309 : (3, 10)
# 			 [ 235 ]- /SMA_power-20dBm/drive_freq31 : (3, 10)
# 			 [ 236 ]- /SMA_power-20dBm/drive_freq310 : (3, 10)
# 			 [ 237 ]- /SMA_power-20dBm/drive_freq311 : (3, 10)
# 			 [ 238 ]- /SMA_power-20dBm/drive_freq312 : (3, 10)
# 			 [ 239 ]- /SMA_power-20dBm/drive_freq313 : (3, 10)
# 			 [ 240 ]- /SMA_power-20dBm/drive_freq314 : (3, 10)
# 			 [ 241 ]- /SMA_power-20dBm/drive_freq315 : (3, 10)
# 			 [ 242 ]- /SMA_power-20dBm/drive_freq316 : (3, 10)
# 			 [ 243 ]- /SMA_power-20dBm/drive_freq317 : (3, 10)
# 			 [ 244 ]- /SMA_power-20dBm/drive_freq318 : (3, 10)
# 			 [ 245 ]- /SMA_power-20dBm/drive_freq319 : (3, 10)
# 			 [ 246 ]- /SMA_power-20dBm/drive_freq32 : (3, 10)
# 			 [ 247 ]- /SMA_power-20dBm/drive_freq320 : (3, 10)
# 			 [ 248 ]- /SMA_power-20dBm/drive_freq321 : (3, 10)
# 			 [ 249 ]- /SMA_power-20dBm/drive_freq322 : (3, 10)
# 			 [ 250 ]- /SMA_power-20dBm/drive_freq323 : (3, 10)
# 			 [ 251 ]- /SMA_power-20dBm/drive_freq324 : (3, 10)
# 			 [ 252 ]- /SMA_power-20dBm/drive_freq325 : (3, 10)
# 			 [ 253 ]- /SMA_power-20dBm/drive_freq326 : (3, 10)
# 			 [ 254 ]- /SMA_power-20dBm/drive_freq327 : (3, 10)
# 			 [ 255 ]- /SMA_power-20dBm/drive_freq328 : (3, 10)
# 			 [ 256 ]- /SMA_power-20dBm/drive_freq329 : (3, 10)
# 			 [ 257 ]- /SMA_power-20dBm/drive_freq33 : (3, 10)
# 			 [ 258 ]- /SMA_power-20dBm/drive_freq330 : (3, 10)
# 			 [ 259 ]- /SMA_power-20dBm/drive_freq331 : (3, 10)
# 			 [ 260 ]- /SMA_power-20dBm/drive_freq332 : (3, 10)
# 			 [ 261 ]- /SMA_power-20dBm/drive_freq333 : (3, 10)
# 			 [ 262 ]- /SMA_power-20dBm/drive_freq334 : (3, 10)
# 			 [ 263 ]- /SMA_power-20dBm/drive_freq335 : (3, 10)
# 			 [ 264 ]- /SMA_power-20dBm/drive_freq336 : (3, 10)
# 			 [ 265 ]- /SMA_power-20dBm/drive_freq337 : (3, 10)
# 			 [ 266 ]- /SMA_power-20dBm/drive_freq338 : (3, 10)
# 			 [ 267 ]- /SMA_power-20dBm/drive_freq339 : (3, 10)
# 			 [ 268 ]- /SMA_power-20dBm/drive_freq34 : (3, 10)
# 			 [ 269 ]- /SMA_power-20dBm/drive_freq340 : (3, 10)
# 			 [ 270 ]- /SMA_power-20dBm/drive_freq341 : (3, 10)
# 			 [ 271 ]- /SMA_power-20dBm/drive_freq342 : (3, 10)
# 			 [ 272 ]- /SMA_power-20dBm/drive_freq343 : (3, 10)
# 			 [ 273 ]- /SMA_power-20dBm/drive_freq344 : (3, 10)
# 			 [ 274 ]- /SMA_power-20dBm/drive_freq345 : (3, 10)
# 			 [ 275 ]- /SMA_power-20dBm/drive_freq346 : (3, 10)
# 			 [ 276 ]- /SMA_power-20dBm/drive_freq347 : (3, 10)
# 			 [ 277 ]- /SMA_power-20dBm/drive_freq348 : (3, 10)
# 			 [ 278 ]- /SMA_power-20dBm/drive_freq349 : (3, 10)
# 			 [ 279 ]- /SMA_power-20dBm/drive_freq35 : (3, 10)
# 			 [ 280 ]- /SMA_power-20dBm/drive_freq350 : (3, 10)
# 			 [ 281 ]- /SMA_power-20dBm/drive_freq351 : (3, 10)
# 			 [ 282 ]- /SMA_power-20dBm/drive_freq352 : (3, 10)
# 			 [ 283 ]- /SMA_power-20dBm/drive_freq353 : (3, 10)
# 			 [ 284 ]- /SMA_power-20dBm/drive_freq354 : (3, 10)
# 			 [ 285 ]- /SMA_power-20dBm/drive_freq355 : (3, 10)
# 			 [ 286 ]- /SMA_power-20dBm/drive_freq356 : (3, 10)
# 			 [ 287 ]- /SMA_power-20dBm/drive_freq357 : (3, 10)
# 			 [ 288 ]- /SMA_power-20dBm/drive_freq358 : (3, 10)
# 			 [ 289 ]- /SMA_power-20dBm/drive_freq359 : (3, 10)
# 			 [ 290 ]- /SMA_power-20dBm/drive_freq36 : (3, 10)
# 			 [ 291 ]- /SMA_power-20dBm/drive_freq360 : (3, 10)
# 			 [ 292 ]- /SMA_power-20dBm/drive_freq361 : (3, 10)
# 			 [ 293 ]- /SMA_power-20dBm/drive_freq362 : (3, 10)
# 			 [ 294 ]- /SMA_power-20dBm/drive_freq363 : (3, 10)
# 			 [ 295 ]- /SMA_power-20dBm/drive_freq364 : (3, 10)
# 			 [ 296 ]- /SMA_power-20dBm/drive_freq365 : (3, 10)
# 			 [ 297 ]- /SMA_power-20dBm/drive_freq366 : (3, 10)
# 			 [ 298 ]- /SMA_power-20dBm/drive_freq367 : (3, 10)
# 			 [ 299 ]- /SMA_power-20dBm/drive_freq368 : (3, 10)
# 			 [ 300 ]- /SMA_power-20dBm/drive_freq369 : (3, 10)
# 			 [ 301 ]- /SMA_power-20dBm/drive_freq37 : (3, 10)
# 			 [ 302 ]- /SMA_power-20dBm/drive_freq370 : (3, 10)
# 			 [ 303 ]- /SMA_power-20dBm/drive_freq371 : (3, 10)
# 			 [ 304 ]- /SMA_power-20dBm/drive_freq372 : (3, 10)
# 			 [ 305 ]- /SMA_power-20dBm/drive_freq373 : (3, 10)
# 			 [ 306 ]- /SMA_power-20dBm/drive_freq374 : (3, 10)
# 			 [ 307 ]- /SMA_power-20dBm/drive_freq375 : (3, 10)
# 			 [ 308 ]- /SMA_power-20dBm/drive_freq376 : (3, 10)
# 			 [ 309 ]- /SMA_power-20dBm/drive_freq377 : (3, 10)
# 			 [ 310 ]- /SMA_power-20dBm/drive_freq378 : (3, 10)
# 			 [ 311 ]- /SMA_power-20dBm/drive_freq379 : (3, 10)
# 			 [ 312 ]- /SMA_power-20dBm/drive_freq38 : (3, 10)
# 			 [ 313 ]- /SMA_power-20dBm/drive_freq380 : (3, 10)
# 			 [ 314 ]- /SMA_power-20dBm/drive_freq381 : (3, 10)
# 			 [ 315 ]- /SMA_power-20dBm/drive_freq382 : (3, 10)
# 			 [ 316 ]- /SMA_power-20dBm/drive_freq383 : (3, 10)
# 			 [ 317 ]- /SMA_power-20dBm/drive_freq384 : (3, 10)
# 			 [ 318 ]- /SMA_power-20dBm/drive_freq385 : (3, 10)
# 			 [ 319 ]- /SMA_power-20dBm/drive_freq386 : (3, 10)
# 			 [ 320 ]- /SMA_power-20dBm/drive_freq387 : (3, 10)
# 			 [ 321 ]- /SMA_power-20dBm/drive_freq388 : (3, 10)
# 			 [ 322 ]- /SMA_power-20dBm/drive_freq389 : (3, 10)
# 			 [ 323 ]- /SMA_power-20dBm/drive_freq39 : (3, 10)
# 			 [ 324 ]- /SMA_power-20dBm/drive_freq390 : (3, 10)
# 			 [ 325 ]- /SMA_power-20dBm/drive_freq391 : (3, 10)
# 			 [ 326 ]- /SMA_power-20dBm/drive_freq392 : (3, 10)
# 			 [ 327 ]- /SMA_power-20dBm/drive_freq393 : (3, 10)
# 			 [ 328 ]- /SMA_power-20dBm/drive_freq394 : (3, 10)
# 			 [ 329 ]- /SMA_power-20dBm/drive_freq395 : (3, 10)
# 			 [ 330 ]- /SMA_power-20dBm/drive_freq396 : (3, 10)
# 			 [ 331 ]- /SMA_power-20dBm/drive_freq397 : (3, 10)
# 			 [ 332 ]- /SMA_power-20dBm/drive_freq398 : (3, 10)
# 			 [ 333 ]- /SMA_power-20dBm/drive_freq399 : (3, 10)
# 			 [ 334 ]- /SMA_power-20dBm/drive_freq4 : (3, 10)
# 			 [ 335 ]- /SMA_power-20dBm/drive_freq40 : (3, 10)
# 			 [ 336 ]- /SMA_power-20dBm/drive_freq400 : (3, 10)
# 			 [ 337 ]- /SMA_power-20dBm/drive_freq401 : (3, 10)
# 			 [ 338 ]- /SMA_power-20dBm/drive_freq402 : (3, 10)
# 			 [ 339 ]- /SMA_power-20dBm/drive_freq403 : (3, 10)
# 			 [ 340 ]- /SMA_power-20dBm/drive_freq404 : (3, 10)
# 			 [ 341 ]- /SMA_power-20dBm/drive_freq405 : (3, 10)
# 			 [ 342 ]- /SMA_power-20dBm/drive_freq406 : (3, 10)
# 			 [ 343 ]- /SMA_power-20dBm/drive_freq407 : (3, 10)
# 			 [ 344 ]- /SMA_power-20dBm/drive_freq408 : (3, 10)
# 			 [ 345 ]- /SMA_power-20dBm/drive_freq409 : (3, 10)
# 			 [ 346 ]- /SMA_power-20dBm/drive_freq41 : (3, 10)
# 			 [ 347 ]- /SMA_power-20dBm/drive_freq410 : (3, 10)
# 			 [ 348 ]- /SMA_power-20dBm/drive_freq411 : (3, 10)
# 			 [ 349 ]- /SMA_power-20dBm/drive_freq412 : (3, 10)
# 			 [ 350 ]- /SMA_power-20dBm/drive_freq413 : (3, 10)
# 			 [ 351 ]- /SMA_power-20dBm/drive_freq414 : (3, 10)
# 			 [ 352 ]- /SMA_power-20dBm/drive_freq415 : (3, 10)
# 			 [ 353 ]- /SMA_power-20dBm/drive_freq416 : (3, 10)
# 			 [ 354 ]- /SMA_power-20dBm/drive_freq417 : (3, 10)
# 			 [ 355 ]- /SMA_power-20dBm/drive_freq418 : (3, 10)
# 			 [ 356 ]- /SMA_power-20dBm/drive_freq419 : (3, 10)
# 			 [ 357 ]- /SMA_power-20dBm/drive_freq42 : (3, 10)
# 			 [ 358 ]- /SMA_power-20dBm/drive_freq420 : (3, 10)
# 			 [ 359 ]- /SMA_power-20dBm/drive_freq421 : (3, 10)
# 			 [ 360 ]- /SMA_power-20dBm/drive_freq422 : (3, 10)
# 			 [ 361 ]- /SMA_power-20dBm/drive_freq423 : (3, 10)
# 			 [ 362 ]- /SMA_power-20dBm/drive_freq424 : (3, 10)
# 			 [ 363 ]- /SMA_power-20dBm/drive_freq425 : (3, 10)
# 			 [ 364 ]- /SMA_power-20dBm/drive_freq426 : (3, 10)
# 			 [ 365 ]- /SMA_power-20dBm/drive_freq427 : (3, 10)
# 			 [ 366 ]- /SMA_power-20dBm/drive_freq428 : (3, 10)
# 			 [ 367 ]- /SMA_power-20dBm/drive_freq429 : (3, 10)
# 			 [ 368 ]- /SMA_power-20dBm/drive_freq43 : (3, 10)
# 			 [ 369 ]- /SMA_power-20dBm/drive_freq430 : (3, 10)
# 			 [ 370 ]- /SMA_power-20dBm/drive_freq431 : (3, 10)
# 			 [ 371 ]- /SMA_power-20dBm/drive_freq432 : (3, 10)
# 			 [ 372 ]- /SMA_power-20dBm/drive_freq433 : (3, 10)
# 			 [ 373 ]- /SMA_power-20dBm/drive_freq434 : (3, 10)
# 			 [ 374 ]- /SMA_power-20dBm/drive_freq435 : (3, 10)
# 			 [ 375 ]- /SMA_power-20dBm/drive_freq436 : (3, 10)
# 			 [ 376 ]- /SMA_power-20dBm/drive_freq437 : (3, 10)
# 			 [ 377 ]- /SMA_power-20dBm/drive_freq438 : (3, 10)
# 			 [ 378 ]- /SMA_power-20dBm/drive_freq439 : (3, 10)
# 			 [ 379 ]- /SMA_power-20dBm/drive_freq44 : (3, 10)
# 			 [ 380 ]- /SMA_power-20dBm/drive_freq440 : (3, 10)
# 			 [ 381 ]- /SMA_power-20dBm/drive_freq441 : (3, 10)
# 			 [ 382 ]- /SMA_power-20dBm/drive_freq442 : (3, 10)
# 			 [ 383 ]- /SMA_power-20dBm/drive_freq443 : (3, 10)
# 			 [ 384 ]- /SMA_power-20dBm/drive_freq444 : (3, 10)
# 			 [ 385 ]- /SMA_power-20dBm/drive_freq445 : (3, 10)
# 			 [ 386 ]- /SMA_power-20dBm/drive_freq446 : (3, 10)
# 			 [ 387 ]- /SMA_power-20dBm/drive_freq447 : (3, 10)
# 			 [ 388 ]- /SMA_power-20dBm/drive_freq448 : (3, 10)
# 			 [ 389 ]- /SMA_power-20dBm/drive_freq449 : (3, 10)
# 			 [ 390 ]- /SMA_power-20dBm/drive_freq45 : (3, 10)
# 			 [ 391 ]- /SMA_power-20dBm/drive_freq450 : (3, 10)
# 			 [ 392 ]- /SMA_power-20dBm/drive_freq451 : (3, 10)
# 			 [ 393 ]- /SMA_power-20dBm/drive_freq452 : (3, 10)
# 			 [ 394 ]- /SMA_power-20dBm/drive_freq453 : (3, 10)
# 			 [ 395 ]- /SMA_power-20dBm/drive_freq454 : (3, 10)
# 			 [ 396 ]- /SMA_power-20dBm/drive_freq455 : (3, 10)
# 			 [ 397 ]- /SMA_power-20dBm/drive_freq456 : (3, 10)
# 			 [ 398 ]- /SMA_power-20dBm/drive_freq457 : (3, 10)
# 			 [ 399 ]- /SMA_power-20dBm/drive_freq458 : (3, 10)
# 			 [ 400 ]- /SMA_power-20dBm/drive_freq459 : (3, 10)
# 			 [ 401 ]- /SMA_power-20dBm/drive_freq46 : (3, 10)
# 			 [ 402 ]- /SMA_power-20dBm/drive_freq460 : (3, 10)
# 			 [ 403 ]- /SMA_power-20dBm/drive_freq461 : (3, 10)
# 			 [ 404 ]- /SMA_power-20dBm/drive_freq462 : (3, 10)
# 			 [ 405 ]- /SMA_power-20dBm/drive_freq463 : (3, 10)
# 			 [ 406 ]- /SMA_power-20dBm/drive_freq464 : (3, 10)
# 			 [ 407 ]- /SMA_power-20dBm/drive_freq465 : (3, 10)
# 			 [ 408 ]- /SMA_power-20dBm/drive_freq466 : (3, 10)
# 			 [ 409 ]- /SMA_power-20dBm/drive_freq467 : (3, 10)
# 			 [ 410 ]- /SMA_power-20dBm/drive_freq468 : (3, 10)
# 			 [ 411 ]- /SMA_power-20dBm/drive_freq469 : (3, 10)
# 			 [ 412 ]- /SMA_power-20dBm/drive_freq47 : (3, 10)
# 			 [ 413 ]- /SMA_power-20dBm/drive_freq470 : (3, 10)
# 			 [ 414 ]- /SMA_power-20dBm/drive_freq471 : (3, 10)
# 			 [ 415 ]- /SMA_power-20dBm/drive_freq472 : (3, 10)
# 			 [ 416 ]- /SMA_power-20dBm/drive_freq473 : (3, 10)
# 			 [ 417 ]- /SMA_power-20dBm/drive_freq474 : (3, 10)
# 			 [ 418 ]- /SMA_power-20dBm/drive_freq475 : (3, 10)
# 			 [ 419 ]- /SMA_power-20dBm/drive_freq476 : (3, 10)
# 			 [ 420 ]- /SMA_power-20dBm/drive_freq477 : (3, 10)
# 			 [ 421 ]- /SMA_power-20dBm/drive_freq478 : (3, 10)
# 			 [ 422 ]- /SMA_power-20dBm/drive_freq479 : (3, 10)
# 			 [ 423 ]- /SMA_power-20dBm/drive_freq48 : (3, 10)
# 			 [ 424 ]- /SMA_power-20dBm/drive_freq480 : (3, 10)
# 			 [ 425 ]- /SMA_power-20dBm/drive_freq481 : (3, 10)
# 			 [ 426 ]- /SMA_power-20dBm/drive_freq482 : (3, 10)
# 			 [ 427 ]- /SMA_power-20dBm/drive_freq483 : (3, 10)
# 			 [ 428 ]- /SMA_power-20dBm/drive_freq484 : (3, 10)
# 			 [ 429 ]- /SMA_power-20dBm/drive_freq485 : (3, 10)
# 			 [ 430 ]- /SMA_power-20dBm/drive_freq486 : (3, 10)
# 			 [ 431 ]- /SMA_power-20dBm/drive_freq487 : (3, 10)
# 			 [ 432 ]- /SMA_power-20dBm/drive_freq488 : (3, 10)
# 			 [ 433 ]- /SMA_power-20dBm/drive_freq489 : (3, 10)
# 			 [ 434 ]- /SMA_power-20dBm/drive_freq49 : (3, 10)
# 			 [ 435 ]- /SMA_power-20dBm/drive_freq490 : (3, 10)
# 			 [ 436 ]- /SMA_power-20dBm/drive_freq491 : (3, 10)
# 			 [ 437 ]- /SMA_power-20dBm/drive_freq492 : (3, 10)
# 			 [ 438 ]- /SMA_power-20dBm/drive_freq493 : (3, 10)
# 			 [ 439 ]- /SMA_power-20dBm/drive_freq494 : (3, 10)
# 			 [ 440 ]- /SMA_power-20dBm/drive_freq495 : (3, 10)
# 			 [ 441 ]- /SMA_power-20dBm/drive_freq496 : (3, 10)
# 			 [ 442 ]- /SMA_power-20dBm/drive_freq497 : (3, 10)
# 			 [ 443 ]- /SMA_power-20dBm/drive_freq498 : (3, 10)
# 			 [ 444 ]- /SMA_power-20dBm/drive_freq499 : (3, 10)
# 			 [ 445 ]- /SMA_power-20dBm/drive_freq5 : (3, 10)
# 			 [ 446 ]- /SMA_power-20dBm/drive_freq50 : (3, 10)
# 			 [ 447 ]- /SMA_power-20dBm/drive_freq500 : (3, 10)
# 			 [ 448 ]- /SMA_power-20dBm/drive_freq501 : (3, 10)
# 			 [ 449 ]- /SMA_power-20dBm/drive_freq502 : (3, 10)
# 			 [ 450 ]- /SMA_power-20dBm/drive_freq503 : (3, 10)
# 			 [ 451 ]- /SMA_power-20dBm/drive_freq504 : (3, 10)
# 			 [ 452 ]- /SMA_power-20dBm/drive_freq505 : (3, 10)
# 			 [ 453 ]- /SMA_power-20dBm/drive_freq506 : (3, 10)
# 			 [ 454 ]- /SMA_power-20dBm/drive_freq507 : (3, 10)
# 			 [ 455 ]- /SMA_power-20dBm/drive_freq508 : (3, 10)
# 			 [ 456 ]- /SMA_power-20dBm/drive_freq509 : (3, 10)
# 			 [ 457 ]- /SMA_power-20dBm/drive_freq51 : (3, 10)
# 			 [ 458 ]- /SMA_power-20dBm/drive_freq510 : (3, 10)
# 			 [ 459 ]- /SMA_power-20dBm/drive_freq511 : (3, 10)
# 			 [ 460 ]- /SMA_power-20dBm/drive_freq512 : (3, 10)
# 			 [ 461 ]- /SMA_power-20dBm/drive_freq513 : (3, 10)
# 			 [ 462 ]- /SMA_power-20dBm/drive_freq514 : (3, 10)
# 			 [ 463 ]- /SMA_power-20dBm/drive_freq515 : (3, 10)
# 			 [ 464 ]- /SMA_power-20dBm/drive_freq516 : (3, 10)
# 			 [ 465 ]- /SMA_power-20dBm/drive_freq517 : (3, 10)
# 			 [ 466 ]- /SMA_power-20dBm/drive_freq518 : (3, 10)
# 			 [ 467 ]- /SMA_power-20dBm/drive_freq519 : (3, 10)
# 			 [ 468 ]- /SMA_power-20dBm/drive_freq52 : (3, 10)
# 			 [ 469 ]- /SMA_power-20dBm/drive_freq520 : (3, 10)
# 			 [ 470 ]- /SMA_power-20dBm/drive_freq521 : (3, 10)
# 			 [ 471 ]- /SMA_power-20dBm/drive_freq522 : (3, 10)
# 			 [ 472 ]- /SMA_power-20dBm/drive_freq523 : (3, 10)
# 			 [ 473 ]- /SMA_power-20dBm/drive_freq524 : (3, 10)
# 			 [ 474 ]- /SMA_power-20dBm/drive_freq525 : (3, 10)
# 			 [ 475 ]- /SMA_power-20dBm/drive_freq526 : (3, 10)
# 			 [ 476 ]- /SMA_power-20dBm/drive_freq527 : (3, 10)
# 			 [ 477 ]- /SMA_power-20dBm/drive_freq528 : (3, 10)
# 			 [ 478 ]- /SMA_power-20dBm/drive_freq529 : (3, 10)
# 			 [ 479 ]- /SMA_power-20dBm/drive_freq53 : (3, 10)
# 			 [ 480 ]- /SMA_power-20dBm/drive_freq530 : (3, 10)
# 			 [ 481 ]- /SMA_power-20dBm/drive_freq531 : (3, 10)
# 			 [ 482 ]- /SMA_power-20dBm/drive_freq532 : (3, 10)
# 			 [ 483 ]- /SMA_power-20dBm/drive_freq533 : (3, 10)
# 			 [ 484 ]- /SMA_power-20dBm/drive_freq534 : (3, 10)
# 			 [ 485 ]- /SMA_power-20dBm/drive_freq535 : (3, 10)
# 			 [ 486 ]- /SMA_power-20dBm/drive_freq536 : (3, 10)
# 			 [ 487 ]- /SMA_power-20dBm/drive_freq537 : (3, 10)
# 			 [ 488 ]- /SMA_power-20dBm/drive_freq538 : (3, 10)
# 			 [ 489 ]- /SMA_power-20dBm/drive_freq539 : (3, 10)
# 			 [ 490 ]- /SMA_power-20dBm/drive_freq54 : (3, 10)
# 			 [ 491 ]- /SMA_power-20dBm/drive_freq540 : (3, 10)
# 			 [ 492 ]- /SMA_power-20dBm/drive_freq541 : (3, 10)
# 			 [ 493 ]- /SMA_power-20dBm/drive_freq542 : (3, 10)
# 			 [ 494 ]- /SMA_power-20dBm/drive_freq543 : (3, 10)
# 			 [ 495 ]- /SMA_power-20dBm/drive_freq544 : (3, 10)
# 			 [ 496 ]- /SMA_power-20dBm/drive_freq545 : (3, 10)
# 			 [ 497 ]- /SMA_power-20dBm/drive_freq546 : (3, 10)
# 			 [ 498 ]- /SMA_power-20dBm/drive_freq547 : (3, 10)
# 			 [ 499 ]- /SMA_power-20dBm/drive_freq548 : (3, 10)
# 			 [ 500 ]- /SMA_power-20dBm/drive_freq549 : (3, 10)
# 			 [ 501 ]- /SMA_power-20dBm/drive_freq55 : (3, 10)
# 			 [ 502 ]- /SMA_power-20dBm/drive_freq550 : (3, 10)
# 			 [ 503 ]- /SMA_power-20dBm/drive_freq551 : (3, 10)
# 			 [ 504 ]- /SMA_power-20dBm/drive_freq552 : (3, 10)
# 			 [ 505 ]- /SMA_power-20dBm/drive_freq553 : (3, 10)
# 			 [ 506 ]- /SMA_power-20dBm/drive_freq554 : (3, 10)
# 			 [ 507 ]- /SMA_power-20dBm/drive_freq555 : (3, 10)
# 			 [ 508 ]- /SMA_power-20dBm/drive_freq556 : (3, 10)
# 			 [ 509 ]- /SMA_power-20dBm/drive_freq557 : (3, 10)
# 			 [ 510 ]- /SMA_power-20dBm/drive_freq558 : (3, 10)
# 			 [ 511 ]- /SMA_power-20dBm/drive_freq559 : (3, 10)
# 			 [ 512 ]- /SMA_power-20dBm/drive_freq56 : (3, 10)
# 			 [ 513 ]- /SMA_power-20dBm/drive_freq560 : (3, 10)
# 			 [ 514 ]- /SMA_power-20dBm/drive_freq561 : (3, 10)
# 			 [ 515 ]- /SMA_power-20dBm/drive_freq562 : (3, 10)
# 			 [ 516 ]- /SMA_power-20dBm/drive_freq563 : (3, 10)
# 			 [ 517 ]- /SMA_power-20dBm/drive_freq564 : (3, 10)
# 			 [ 518 ]- /SMA_power-20dBm/drive_freq565 : (3, 10)
# 			 [ 519 ]- /SMA_power-20dBm/drive_freq566 : (3, 10)
# 			 [ 520 ]- /SMA_power-20dBm/drive_freq567 : (3, 10)
# 			 [ 521 ]- /SMA_power-20dBm/drive_freq568 : (3, 10)
# 			 [ 522 ]- /SMA_power-20dBm/drive_freq569 : (3, 10)
# 			 [ 523 ]- /SMA_power-20dBm/drive_freq57 : (3, 10)
# 			 [ 524 ]- /SMA_power-20dBm/drive_freq570 : (3, 10)
# 			 [ 525 ]- /SMA_power-20dBm/drive_freq571 : (3, 10)
# 			 [ 526 ]- /SMA_power-20dBm/drive_freq572 : (3, 10)
# 			 [ 527 ]- /SMA_power-20dBm/drive_freq573 : (3, 10)
# 			 [ 528 ]- /SMA_power-20dBm/drive_freq574 : (3, 10)
# 			 [ 529 ]- /SMA_power-20dBm/drive_freq575 : (3, 10)
# 			 [ 530 ]- /SMA_power-20dBm/drive_freq576 : (3, 10)
# 			 [ 531 ]- /SMA_power-20dBm/drive_freq577 : (3, 10)
# 			 [ 532 ]- /SMA_power-20dBm/drive_freq578 : (3, 10)
# 			 [ 533 ]- /SMA_power-20dBm/drive_freq579 : (3, 10)
# 			 [ 534 ]- /SMA_power-20dBm/drive_freq58 : (3, 10)
# 			 [ 535 ]- /SMA_power-20dBm/drive_freq580 : (3, 10)
# 			 [ 536 ]- /SMA_power-20dBm/drive_freq581 : (3, 10)
# 			 [ 537 ]- /SMA_power-20dBm/drive_freq582 : (3, 10)
# 			 [ 538 ]- /SMA_power-20dBm/drive_freq583 : (3, 10)
# 			 [ 539 ]- /SMA_power-20dBm/drive_freq584 : (3, 10)
# 			 [ 540 ]- /SMA_power-20dBm/drive_freq585 : (3, 10)
# 			 [ 541 ]- /SMA_power-20dBm/drive_freq586 : (3, 10)
# 			 [ 542 ]- /SMA_power-20dBm/drive_freq587 : (3, 10)
# 			 [ 543 ]- /SMA_power-20dBm/drive_freq588 : (3, 10)
# 			 [ 544 ]- /SMA_power-20dBm/drive_freq589 : (3, 10)
# 			 [ 545 ]- /SMA_power-20dBm/drive_freq59 : (3, 10)
# 			 [ 546 ]- /SMA_power-20dBm/drive_freq590 : (3, 10)
# 			 [ 547 ]- /SMA_power-20dBm/drive_freq591 : (3, 10)
# 			 [ 548 ]- /SMA_power-20dBm/drive_freq592 : (3, 10)
# 			 [ 549 ]- /SMA_power-20dBm/drive_freq593 : (3, 10)
# 			 [ 550 ]- /SMA_power-20dBm/drive_freq594 : (3, 10)
# 			 [ 551 ]- /SMA_power-20dBm/drive_freq595 : (3, 10)
# 			 [ 552 ]- /SMA_power-20dBm/drive_freq596 : (3, 10)
# 			 [ 553 ]- /SMA_power-20dBm/drive_freq597 : (3, 10)
# 			 [ 554 ]- /SMA_power-20dBm/drive_freq598 : (3, 10)
# 			 [ 555 ]- /SMA_power-20dBm/drive_freq599 : (3, 10)
# 			 [ 556 ]- /SMA_power-20dBm/drive_freq6 : (3, 10)
# 			 [ 557 ]- /SMA_power-20dBm/drive_freq60 : (3, 10)
# 			 [ 558 ]- /SMA_power-20dBm/drive_freq600 : (3, 10)
# 			 [ 559 ]- /SMA_power-20dBm/drive_freq601 : (3, 10)
# 			 [ 560 ]- /SMA_power-20dBm/drive_freq602 : (3, 10)
# 			 [ 561 ]- /SMA_power-20dBm/drive_freq603 : (3, 10)
# 			 [ 562 ]- /SMA_power-20dBm/drive_freq604 : (3, 10)
# 			 [ 563 ]- /SMA_power-20dBm/drive_freq605 : (3, 10)
# 			 [ 564 ]- /SMA_power-20dBm/drive_freq606 : (3, 10)
# 			 [ 565 ]- /SMA_power-20dBm/drive_freq607 : (3, 10)
# 			 [ 566 ]- /SMA_power-20dBm/drive_freq608 : (3, 10)
# 			 [ 567 ]- /SMA_power-20dBm/drive_freq609 : (3, 10)
# 			 [ 568 ]- /SMA_power-20dBm/drive_freq61 : (3, 10)
# 			 [ 569 ]- /SMA_power-20dBm/drive_freq610 : (3, 10)
# 			 [ 570 ]- /SMA_power-20dBm/drive_freq611 : (3, 10)
# 			 [ 571 ]- /SMA_power-20dBm/drive_freq612 : (3, 10)
# 			 [ 572 ]- /SMA_power-20dBm/drive_freq613 : (3, 10)
# 			 [ 573 ]- /SMA_power-20dBm/drive_freq614 : (3, 10)
# 			 [ 574 ]- /SMA_power-20dBm/drive_freq615 : (3, 10)
# 			 [ 575 ]- /SMA_power-20dBm/drive_freq616 : (3, 10)
# 			 [ 576 ]- /SMA_power-20dBm/drive_freq617 : (3, 10)
# 			 [ 577 ]- /SMA_power-20dBm/drive_freq618 : (3, 10)
# 			 [ 578 ]- /SMA_power-20dBm/drive_freq619 : (3, 10)
# 			 [ 579 ]- /SMA_power-20dBm/drive_freq62 : (3, 10)
# 			 [ 580 ]- /SMA_power-20dBm/drive_freq620 : (3, 10)
# 			 [ 581 ]- /SMA_power-20dBm/drive_freq621 : (3, 10)
# 			 [ 582 ]- /SMA_power-20dBm/drive_freq622 : (3, 10)
# 			 [ 583 ]- /SMA_power-20dBm/drive_freq623 : (3, 10)
# 			 [ 584 ]- /SMA_power-20dBm/drive_freq624 : (3, 10)
# 			 [ 585 ]- /SMA_power-20dBm/drive_freq625 : (3, 10)
# 			 [ 586 ]- /SMA_power-20dBm/drive_freq626 : (3, 10)
# 			 [ 587 ]- /SMA_power-20dBm/drive_freq627 : (3, 10)
# 			 [ 588 ]- /SMA_power-20dBm/drive_freq628 : (3, 10)
# 			 [ 589 ]- /SMA_power-20dBm/drive_freq629 : (3, 10)
# 			 [ 590 ]- /SMA_power-20dBm/drive_freq63 : (3, 10)
# 			 [ 591 ]- /SMA_power-20dBm/drive_freq630 : (3, 10)
# 			 [ 592 ]- /SMA_power-20dBm/drive_freq631 : (3, 10)
# 			 [ 593 ]- /SMA_power-20dBm/drive_freq632 : (3, 10)
# 			 [ 594 ]- /SMA_power-20dBm/drive_freq633 : (3, 10)
# 			 [ 595 ]- /SMA_power-20dBm/drive_freq634 : (3, 10)
# 			 [ 596 ]- /SMA_power-20dBm/drive_freq635 : (3, 10)
# 			 [ 597 ]- /SMA_power-20dBm/drive_freq636 : (3, 10)
# 			 [ 598 ]- /SMA_power-20dBm/drive_freq637 : (3, 10)
# 			 [ 599 ]- /SMA_power-20dBm/drive_freq638 : (3, 10)
# 			 [ 600 ]- /SMA_power-20dBm/drive_freq639 : (3, 10)
# 			 [ 601 ]- /SMA_power-20dBm/drive_freq64 : (3, 10)
# 			 [ 602 ]- /SMA_power-20dBm/drive_freq640 : (3, 10)
# 			 [ 603 ]- /SMA_power-20dBm/drive_freq641 : (3, 10)
# 			 [ 604 ]- /SMA_power-20dBm/drive_freq642 : (3, 10)
# 			 [ 605 ]- /SMA_power-20dBm/drive_freq643 : (3, 10)
# 			 [ 606 ]- /SMA_power-20dBm/drive_freq644 : (3, 10)
# 			 [ 607 ]- /SMA_power-20dBm/drive_freq645 : (3, 10)
# 			 [ 608 ]- /SMA_power-20dBm/drive_freq646 : (3, 10)
# 			 [ 609 ]- /SMA_power-20dBm/drive_freq647 : (3, 10)
# 			 [ 610 ]- /SMA_power-20dBm/drive_freq648 : (3, 10)
# 			 [ 611 ]- /SMA_power-20dBm/drive_freq649 : (3, 10)
# 			 [ 612 ]- /SMA_power-20dBm/drive_freq65 : (3, 10)
# 			 [ 613 ]- /SMA_power-20dBm/drive_freq650 : (3, 10)
# 			 [ 614 ]- /SMA_power-20dBm/drive_freq651 : (3, 10)
# 			 [ 615 ]- /SMA_power-20dBm/drive_freq652 : (3, 10)
# 			 [ 616 ]- /SMA_power-20dBm/drive_freq653 : (3, 10)
# 			 [ 617 ]- /SMA_power-20dBm/drive_freq654 : (3, 10)
# 			 [ 618 ]- /SMA_power-20dBm/drive_freq655 : (3, 10)
# 			 [ 619 ]- /SMA_power-20dBm/drive_freq656 : (3, 10)
# 			 [ 620 ]- /SMA_power-20dBm/drive_freq657 : (3, 10)
# 			 [ 621 ]- /SMA_power-20dBm/drive_freq658 : (3, 10)
# 			 [ 622 ]- /SMA_power-20dBm/drive_freq659 : (3, 10)
# 			 [ 623 ]- /SMA_power-20dBm/drive_freq66 : (3, 10)
# 			 [ 624 ]- /SMA_power-20dBm/drive_freq660 : (3, 10)
# 			 [ 625 ]- /SMA_power-20dBm/drive_freq661 : (3, 10)
# 			 [ 626 ]- /SMA_power-20dBm/drive_freq662 : (3, 10)
# 			 [ 627 ]- /SMA_power-20dBm/drive_freq663 : (3, 10)
# 			 [ 628 ]- /SMA_power-20dBm/drive_freq664 : (3, 10)
# 			 [ 629 ]- /SMA_power-20dBm/drive_freq665 : (3, 10)
# 			 [ 630 ]- /SMA_power-20dBm/drive_freq666 : (3, 10)
# 			 [ 631 ]- /SMA_power-20dBm/drive_freq667 : (3, 10)
# 			 [ 632 ]- /SMA_power-20dBm/drive_freq668 : (3, 10)
# 			 [ 633 ]- /SMA_power-20dBm/drive_freq669 : (3, 10)
# 			 [ 634 ]- /SMA_power-20dBm/drive_freq67 : (3, 10)
# 			 [ 635 ]- /SMA_power-20dBm/drive_freq670 : (3, 10)
# 			 [ 636 ]- /SMA_power-20dBm/drive_freq671 : (3, 10)
# 			 [ 637 ]- /SMA_power-20dBm/drive_freq672 : (3, 10)
# 			 [ 638 ]- /SMA_power-20dBm/drive_freq673 : (3, 10)
# 			 [ 639 ]- /SMA_power-20dBm/drive_freq674 : (3, 10)
# 			 [ 640 ]- /SMA_power-20dBm/drive_freq675 : (3, 10)
# 			 [ 641 ]- /SMA_power-20dBm/drive_freq676 : (3, 10)
# 			 [ 642 ]- /SMA_power-20dBm/drive_freq677 : (3, 10)
# 			 [ 643 ]- /SMA_power-20dBm/drive_freq678 : (3, 10)
# 			 [ 644 ]- /SMA_power-20dBm/drive_freq679 : (3, 10)
# 			 [ 645 ]- /SMA_power-20dBm/drive_freq68 : (3, 10)
# 			 [ 646 ]- /SMA_power-20dBm/drive_freq680 : (3, 10)
# 			 [ 647 ]- /SMA_power-20dBm/drive_freq681 : (3, 10)
# 			 [ 648 ]- /SMA_power-20dBm/drive_freq682 : (3, 10)
# 			 [ 649 ]- /SMA_power-20dBm/drive_freq683 : (3, 10)
# 			 [ 650 ]- /SMA_power-20dBm/drive_freq684 : (3, 10)
# 			 [ 651 ]- /SMA_power-20dBm/drive_freq685 : (3, 10)
# 			 [ 652 ]- /SMA_power-20dBm/drive_freq686 : (3, 10)
# 			 [ 653 ]- /SMA_power-20dBm/drive_freq687 : (3, 10)
# 			 [ 654 ]- /SMA_power-20dBm/drive_freq688 : (3, 10)
# 			 [ 655 ]- /SMA_power-20dBm/drive_freq689 : (3, 10)
# 			 [ 656 ]- /SMA_power-20dBm/drive_freq69 : (3, 10)
# 			 [ 657 ]- /SMA_power-20dBm/drive_freq690 : (3, 10)
# 			 [ 658 ]- /SMA_power-20dBm/drive_freq691 : (3, 10)
# 			 [ 659 ]- /SMA_power-20dBm/drive_freq692 : (3, 10)
# 			 [ 660 ]- /SMA_power-20dBm/drive_freq693 : (3, 10)
# 			 [ 661 ]- /SMA_power-20dBm/drive_freq694 : (3, 10)
# 			 [ 662 ]- /SMA_power-20dBm/drive_freq695 : (3, 10)
# 			 [ 663 ]- /SMA_power-20dBm/drive_freq696 : (3, 10)
# 			 [ 664 ]- /SMA_power-20dBm/drive_freq697 : (3, 10)
# 			 [ 665 ]- /SMA_power-20dBm/drive_freq698 : (3, 10)
# 			 [ 666 ]- /SMA_power-20dBm/drive_freq699 : (3, 10)
# 			 [ 667 ]- /SMA_power-20dBm/drive_freq7 : (3, 10)
# 			 [ 668 ]- /SMA_power-20dBm/drive_freq70 : (3, 10)
# 			 [ 669 ]- /SMA_power-20dBm/drive_freq700 : (3, 10)
# 			 [ 670 ]- /SMA_power-20dBm/drive_freq701 : (3, 10)
# 			 [ 671 ]- /SMA_power-20dBm/drive_freq702 : (3, 10)
# 			 [ 672 ]- /SMA_power-20dBm/drive_freq703 : (3, 10)
# 			 [ 673 ]- /SMA_power-20dBm/drive_freq704 : (3, 10)
# 			 [ 674 ]- /SMA_power-20dBm/drive_freq705 : (3, 10)
# 			 [ 675 ]- /SMA_power-20dBm/drive_freq706 : (3, 10)
# 			 [ 676 ]- /SMA_power-20dBm/drive_freq707 : (3, 10)
# 			 [ 677 ]- /SMA_power-20dBm/drive_freq708 : (3, 10)
# 			 [ 678 ]- /SMA_power-20dBm/drive_freq709 : (3, 10)
# 			 [ 679 ]- /SMA_power-20dBm/drive_freq71 : (3, 10)
# 			 [ 680 ]- /SMA_power-20dBm/drive_freq710 : (3, 10)
# 			 [ 681 ]- /SMA_power-20dBm/drive_freq711 : (3, 10)
# 			 [ 682 ]- /SMA_power-20dBm/drive_freq712 : (3, 10)
# 			 [ 683 ]- /SMA_power-20dBm/drive_freq713 : (3, 10)
# 			 [ 684 ]- /SMA_power-20dBm/drive_freq714 : (3, 10)
# 			 [ 685 ]- /SMA_power-20dBm/drive_freq715 : (3, 10)
# 			 [ 686 ]- /SMA_power-20dBm/drive_freq716 : (3, 10)
# 			 [ 687 ]- /SMA_power-20dBm/drive_freq717 : (3, 10)
# 			 [ 688 ]- /SMA_power-20dBm/drive_freq718 : (3, 10)
# 			 [ 689 ]- /SMA_power-20dBm/drive_freq719 : (3, 10)
# 			 [ 690 ]- /SMA_power-20dBm/drive_freq72 : (3, 10)
# 			 [ 691 ]- /SMA_power-20dBm/drive_freq720 : (3, 10)
# 			 [ 692 ]- /SMA_power-20dBm/drive_freq721 : (3, 10)
# 			 [ 693 ]- /SMA_power-20dBm/drive_freq722 : (3, 10)
# 			 [ 694 ]- /SMA_power-20dBm/drive_freq723 : (3, 10)
# 			 [ 695 ]- /SMA_power-20dBm/drive_freq724 : (3, 10)
# 			 [ 696 ]- /SMA_power-20dBm/drive_freq725 : (3, 10)
# 			 [ 697 ]- /SMA_power-20dBm/drive_freq726 : (3, 10)
# 			 [ 698 ]- /SMA_power-20dBm/drive_freq727 : (3, 10)
# 			 [ 699 ]- /SMA_power-20dBm/drive_freq728 : (3, 10)
# 			 [ 700 ]- /SMA_power-20dBm/drive_freq729 : (3, 10)
# 			 [ 701 ]- /SMA_power-20dBm/drive_freq73 : (3, 10)
# 			 [ 702 ]- /SMA_power-20dBm/drive_freq730 : (3, 10)
# 			 [ 703 ]- /SMA_power-20dBm/drive_freq731 : (3, 10)
# 			 [ 704 ]- /SMA_power-20dBm/drive_freq732 : (3, 10)
# 			 [ 705 ]- /SMA_power-20dBm/drive_freq733 : (3, 10)
# 			 [ 706 ]- /SMA_power-20dBm/drive_freq734 : (3, 10)
# 			 [ 707 ]- /SMA_power-20dBm/drive_freq735 : (3, 10)
# 			 [ 708 ]- /SMA_power-20dBm/drive_freq736 : (3, 10)
# 			 [ 709 ]- /SMA_power-20dBm/drive_freq737 : (3, 10)
# 			 [ 710 ]- /SMA_power-20dBm/drive_freq738 : (3, 10)
# 			 [ 711 ]- /SMA_power-20dBm/drive_freq739 : (3, 10)
# 			 [ 712 ]- /SMA_power-20dBm/drive_freq74 : (3, 10)
# 			 [ 713 ]- /SMA_power-20dBm/drive_freq740 : (3, 10)
# 			 [ 714 ]- /SMA_power-20dBm/drive_freq741 : (3, 10)
# 			 [ 715 ]- /SMA_power-20dBm/drive_freq742 : (3, 10)
# 			 [ 716 ]- /SMA_power-20dBm/drive_freq743 : (3, 10)
# 			 [ 717 ]- /SMA_power-20dBm/drive_freq744 : (3, 10)
# 			 [ 718 ]- /SMA_power-20dBm/drive_freq745 : (3, 10)
# 			 [ 719 ]- /SMA_power-20dBm/drive_freq746 : (3, 10)
# 			 [ 720 ]- /SMA_power-20dBm/drive_freq747 : (3, 10)
# 			 [ 721 ]- /SMA_power-20dBm/drive_freq748 : (3, 10)
# 			 [ 722 ]- /SMA_power-20dBm/drive_freq749 : (3, 10)
# 			 [ 723 ]- /SMA_power-20dBm/drive_freq75 : (3, 10)
# 			 [ 724 ]- /SMA_power-20dBm/drive_freq750 : (3, 10)
# 			 [ 725 ]- /SMA_power-20dBm/drive_freq751 : (3, 10)
# 			 [ 726 ]- /SMA_power-20dBm/drive_freq752 : (3, 10)
# 			 [ 727 ]- /SMA_power-20dBm/drive_freq753 : (3, 10)
# 			 [ 728 ]- /SMA_power-20dBm/drive_freq754 : (3, 10)
# 			 [ 729 ]- /SMA_power-20dBm/drive_freq755 : (3, 10)
# 			 [ 730 ]- /SMA_power-20dBm/drive_freq756 : (3, 10)
# 			 [ 731 ]- /SMA_power-20dBm/drive_freq757 : (3, 10)
# 			 [ 732 ]- /SMA_power-20dBm/drive_freq758 : (3, 10)
# 			 [ 733 ]- /SMA_power-20dBm/drive_freq759 : (3, 10)
# 			 [ 734 ]- /SMA_power-20dBm/drive_freq76 : (3, 10)
# 			 [ 735 ]- /SMA_power-20dBm/drive_freq760 : (3, 10)
# 			 [ 736 ]- /SMA_power-20dBm/drive_freq761 : (3, 10)
# 			 [ 737 ]- /SMA_power-20dBm/drive_freq762 : (3, 10)
# 			 [ 738 ]- /SMA_power-20dBm/drive_freq763 : (3, 10)
# 			 [ 739 ]- /SMA_power-20dBm/drive_freq764 : (3, 10)
# 			 [ 740 ]- /SMA_power-20dBm/drive_freq765 : (3, 10)
# 			 [ 741 ]- /SMA_power-20dBm/drive_freq766 : (3, 10)
# 			 [ 742 ]- /SMA_power-20dBm/drive_freq767 : (3, 10)
# 			 [ 743 ]- /SMA_power-20dBm/drive_freq768 : (3, 10)
# 			 [ 744 ]- /SMA_power-20dBm/drive_freq769 : (3, 10)
# 			 [ 745 ]- /SMA_power-20dBm/drive_freq77 : (3, 10)
# 			 [ 746 ]- /SMA_power-20dBm/drive_freq770 : (3, 10)
# 			 [ 747 ]- /SMA_power-20dBm/drive_freq771 : (3, 10)
# 			 [ 748 ]- /SMA_power-20dBm/drive_freq772 : (3, 10)
# 			 [ 749 ]- /SMA_power-20dBm/drive_freq773 : (3, 10)
# 			 [ 750 ]- /SMA_power-20dBm/drive_freq774 : (3, 10)
# 			 [ 751 ]- /SMA_power-20dBm/drive_freq775 : (3, 10)
# 			 [ 752 ]- /SMA_power-20dBm/drive_freq776 : (3, 10)
# 			 [ 753 ]- /SMA_power-20dBm/drive_freq777 : (3, 10)
# 			 [ 754 ]- /SMA_power-20dBm/drive_freq778 : (3, 10)
# 			 [ 755 ]- /SMA_power-20dBm/drive_freq779 : (3, 10)
# 			 [ 756 ]- /SMA_power-20dBm/drive_freq78 : (3, 10)
# 			 [ 757 ]- /SMA_power-20dBm/drive_freq780 : (3, 10)
# 			 [ 758 ]- /SMA_power-20dBm/drive_freq781 : (3, 10)
# 			 [ 759 ]- /SMA_power-20dBm/drive_freq782 : (3, 10)
# 			 [ 760 ]- /SMA_power-20dBm/drive_freq783 : (3, 10)
# 			 [ 761 ]- /SMA_power-20dBm/drive_freq784 : (3, 10)
# 			 [ 762 ]- /SMA_power-20dBm/drive_freq785 : (3, 10)
# 			 [ 763 ]- /SMA_power-20dBm/drive_freq786 : (3, 10)
# 			 [ 764 ]- /SMA_power-20dBm/drive_freq787 : (3, 10)
# 			 [ 765 ]- /SMA_power-20dBm/drive_freq788 : (3, 10)
# 			 [ 766 ]- /SMA_power-20dBm/drive_freq789 : (3, 10)
# 			 [ 767 ]- /SMA_power-20dBm/drive_freq79 : (3, 10)
# 			 [ 768 ]- /SMA_power-20dBm/drive_freq790 : (3, 10)
# 			 [ 769 ]- /SMA_power-20dBm/drive_freq791 : (3, 10)
# 			 [ 770 ]- /SMA_power-20dBm/drive_freq792 : (3, 10)
# 			 [ 771 ]- /SMA_power-20dBm/drive_freq793 : (3, 10)
# 			 [ 772 ]- /SMA_power-20dBm/drive_freq794 : (3, 10)
# 			 [ 773 ]- /SMA_power-20dBm/drive_freq795 : (3, 10)
# 			 [ 774 ]- /SMA_power-20dBm/drive_freq796 : (3, 10)
# 			 [ 775 ]- /SMA_power-20dBm/drive_freq797 : (3, 10)
# 			 [ 776 ]- /SMA_power-20dBm/drive_freq798 : (3, 10)
# 			 [ 777 ]- /SMA_power-20dBm/drive_freq799 : (3, 10)
# 			 [ 778 ]- /SMA_power-20dBm/drive_freq8 : (3, 10)
# 			 [ 779 ]- /SMA_power-20dBm/drive_freq80 : (3, 10)
# 			 [ 780 ]- /SMA_power-20dBm/drive_freq81 : (3, 10)
# 			 [ 781 ]- /SMA_power-20dBm/drive_freq82 : (3, 10)
# 			 [ 782 ]- /SMA_power-20dBm/drive_freq83 : (3, 10)
# 			 [ 783 ]- /SMA_power-20dBm/drive_freq84 : (3, 10)
# 			 [ 784 ]- /SMA_power-20dBm/drive_freq85 : (3, 10)
# 			 [ 785 ]- /SMA_power-20dBm/drive_freq86 : (3, 10)
# 			 [ 786 ]- /SMA_power-20dBm/drive_freq87 : (3, 10)
# 			 [ 787 ]- /SMA_power-20dBm/drive_freq88 : (3, 10)
# 			 [ 788 ]- /SMA_power-20dBm/drive_freq89 : (3, 10)
# 			 [ 789 ]- /SMA_power-20dBm/drive_freq9 : (3, 10)
# 			 [ 790 ]- /SMA_power-20dBm/drive_freq90 : (3, 10)
# 			 [ 791 ]- /SMA_power-20dBm/drive_freq91 : (3, 10)
# 			 [ 792 ]- /SMA_power-20dBm/drive_freq92 : (3, 10)
# 			 [ 793 ]- /SMA_power-20dBm/drive_freq93 : (3, 10)
# 			 [ 794 ]- /SMA_power-20dBm/drive_freq94 : (3, 10)
# 			 [ 795 ]- /SMA_power-20dBm/drive_freq95 : (3, 10)
# 			 [ 796 ]- /SMA_power-20dBm/drive_freq96 : (3, 10)
# 			 [ 797 ]- /SMA_power-20dBm/drive_freq97 : (3, 10)
# 			 [ 798 ]- /SMA_power-20dBm/drive_freq98 : (3, 10)
# 			 [ 799 ]- /SMA_power-20dBm/drive_freq99 : (3, 10)
# 			 [ 800 ]- /SMA_power-20dBm/parameters : (2, 8)

# %%
sma_pow = -20 #[dBm]
params_names, params_values = getDatasetValue(filename,"/SMA_power"+str(sma_pow)+"dBm/",-1)
#params_names
# Out:
# sma_pow :  -20
# vna_pow :  -20
# vna_freq_start :  8574000000.0
# vna_freq_stop :  8575000000.0
# fmin_sma :  6000000000.0
# fmax_sma :  6800000000.0
# nfreqs :  1440
# npoints :  400

# %%
"""Get simulation parameters"""
# Print [Check if the order of paramerers is the same of the assegnation below!]
for i in np.arange(0,len(params_names)):
    print(str(params_names[i].decode("utf-8")),": ",str(params_values[i].decode("utf-8")))


sma_pow = -20 #[dBm]
params_names, params_values = getDatasetValue(filename,"/SMA_power"+str(sma_pow)+"dBm/",-1)

# Print [Check if the order of paramerers is the same of the assegnation below!]
for i in np.arange(0,len(params_names)):
    print(str(params_names[i].decode("utf-8")),": ",str(params_values[i].decode("utf-8")))

# Vna
powerdBm = float(params_values[1]) #[dBm]
npts = int(params_values[7])
vna_freq_start = float(params_values[2])
vna_freq_stop = float(params_values[3])
# Sma
freq_start = float(params_values[4])/1e9 #[GHz]
freq_stop = float(params_values[5])/1e9 #[Ghz]
n_freq = int(params_values[6])

freqs = np.linspace(freq_start, freq_stop, n_freq) 
vna_freqs = np.linspace(vna_freq_start, vna_freq_stop, npts)

"""Print parameters arrays"""
print("\n\nIndex:\n")
temp_str = ""
freq_cifers = 3
for i in np.arange(0,n_freq):
    temp_str = temp_str + "[" + str(i) + "] " + str(round(freqs[i], freq_cifers)) + "; "
print("SMA frequencies (GHz): ",temp_str)
# Out:
# sma_pow :  -20
# vna_pow :  -20
# vna_freq_start :  8574000000.0
# vna_freq_stop :  8575000000.0
# fmin_sma :  6000000000.0
# fmax_sma :  6800000000.0
# nfreqs :  1440
# npoints :  400
# sma_pow :  -20
# vna_pow :  -20
# vna_freq_start :  8574000000.0
# vna_freq_stop :  8575000000.0
# fmin_sma :  6000000000.0
# fmax_sma :  6800000000.0
# nfreqs :  1440
# npoints :  400
#
#
# Index:
#
# SMA frequencies (GHz):  [0] 6.0; [1] 6.001; [2] 6.001; [3] 6.002; [4] 6.002; [5] 6.003; [6] 6.003; [7] 6.004; [8] 6.004; [9] 6.005; [10] 6.006; [11] 6.006; [12] 6.007; [13] 6.007; [14] 6.008; [15] 6.008; [16] 6.009; [17] 6.009; [18] 6.01; [19] 6.011; [20] 6.011; [21] 6.012; [22] 6.012; [23] 6.013; [24] 6.013; [25] 6.014; [26] 6.014; [27] 6.015; [28] 6.016; [29] 6.016; [30] 6.017; [31] 6.017; [32] 6.018; [33] 6.018; [34] 6.019; [35] 6.019; [36] 6.02; [37] 6.021; [38] 6.021; [39] 6.022; [40] 6.022; [41] 6.023; [42] 6.023; [43] 6.024; [44] 6.024; [45] 6.025; [46] 6.026; [47] 6.026; [48] 6.027; [49] 6.027; [50] 6.028; [51] 6.028; [52] 6.029; [53] 6.029; [54] 6.03; [55] 6.031; [56] 6.031; [57] 6.032; [58] 6.032; [59] 6.033; [60] 6.033; [61] 6.034; [62] 6.034; [63] 6.035; [64] 6.036; [65] 6.036; [66] 6.037; [67] 6.037; [68] 6.038; [69] 6.038; [70] 6.039; [71] 6.039; [72] 6.04; [73] 6.041; [74] 6.041; [75] 6.042; [76] 6.042; [77] 6.043; [78] 6.043; [79] 6.044; [80] 6.044; [81] 6.045; [82] 6.046; [83] 6.046; [84] 6.047; [85] 6.047; [86] 6.048; [87] 6.048; [88] 6.049; [89] 6.049; [90] 6.05; [91] 6.051; [92] 6.051; [93] 6.052; [94] 6.052; [95] 6.053; [96] 6.053; [97] 6.054; [98] 6.054; [99] 6.055; [100] 6.056; [101] 6.056; [102] 6.057; [103] 6.057; [104] 6.058; [105] 6.058; [106] 6.059; [107] 6.059; [108] 6.06; [109] 6.061; [110] 6.061; [111] 6.062; [112] 6.062; [113] 6.063; [114] 6.063; [115] 6.064; [116] 6.064; [117] 6.065; [118] 6.066; [119] 6.066; [120] 6.067; [121] 6.067; [122] 6.068; [123] 6.068; [124] 6.069; [125] 6.069; [126] 6.07; [127] 6.071; [128] 6.071; [129] 6.072; [130] 6.072; [131] 6.073; [132] 6.073; [133] 6.074; [134] 6.074; [135] 6.075; [136] 6.076; [137] 6.076; [138] 6.077; [139] 6.077; [140] 6.078; [141] 6.078; [142] 6.079; [143] 6.079; [144] 6.08; [145] 6.081; [146] 6.081; [147] 6.082; [148] 6.082; [149] 6.083; [150] 6.083; [151] 6.084; [152] 6.085; [153] 6.085; [154] 6.086; [155] 6.086; [156] 6.087; [157] 6.087; [158] 6.088; [159] 6.088; [160] 6.089; [161] 6.09; [162] 6.09; [163] 6.091; [164] 6.091; [165] 6.092; [166] 6.092; [167] 6.093; [168] 6.093; [169] 6.094; [170] 6.095; [171] 6.095; [172] 6.096; [173] 6.096; [174] 6.097; [175] 6.097; [176] 6.098; [177] 6.098; [178] 6.099; [179] 6.1; [180] 6.1; [181] 6.101; [182] 6.101; [183] 6.102; [184] 6.102; [185] 6.103; [186] 6.103; [187] 6.104; [188] 6.105; [189] 6.105; [190] 6.106; [191] 6.106; [192] 6.107; [193] 6.107; [194] 6.108; [195] 6.108; [196] 6.109; [197] 6.11; [198] 6.11; [199] 6.111; [200] 6.111; [201] 6.112; [202] 6.112; [203] 6.113; [204] 6.113; [205] 6.114; [206] 6.115; [207] 6.115; [208] 6.116; [209] 6.116; [210] 6.117; [211] 6.117; [212] 6.118; [213] 6.118; [214] 6.119; [215] 6.12; [216] 6.12; [217] 6.121; [218] 6.121; [219] 6.122; [220] 6.122; [221] 6.123; [222] 6.123; [223] 6.124; [224] 6.125; [225] 6.125; [226] 6.126; [227] 6.126; [228] 6.127; [229] 6.127; [230] 6.128; [231] 6.128; [232] 6.129; [233] 6.13; [234] 6.13; [235] 6.131; [236] 6.131; [237] 6.132; [238] 6.132; [239] 6.133; [240] 6.133; [241] 6.134; [242] 6.135; [243] 6.135; [244] 6.136; [245] 6.136; [246] 6.137; [247] 6.137; [248] 6.138; [249] 6.138; [250] 6.139; [251] 6.14; [252] 6.14; [253] 6.141; [254] 6.141; [255] 6.142; [256] 6.142; [257] 6.143; [258] 6.143; [259] 6.144; [260] 6.145; [261] 6.145; [262] 6.146; [263] 6.146; [264] 6.147; [265] 6.147; [266] 6.148; [267] 6.148; [268] 6.149; [269] 6.15; [270] 6.15; [271] 6.151; [272] 6.151; [273] 6.152; [274] 6.152; [275] 6.153; [276] 6.153; [277] 6.154; [278] 6.155; [279] 6.155; [280] 6.156; [281] 6.156; [282] 6.157; [283] 6.157; [284] 6.158; [285] 6.158; [286] 6.159; [287] 6.16; [288] 6.16; [289] 6.161; [290] 6.161; [291] 6.162; [292] 6.162; [293] 6.163; [294] 6.163; [295] 6.164; [296] 6.165; [297] 6.165; [298] 6.166; [299] 6.166; [300] 6.167; [301] 6.167; [302] 6.168; [303] 6.168; [304] 6.169; [305] 6.17; [306] 6.17; [307] 6.171; [308] 6.171; [309] 6.172; [310] 6.172; [311] 6.173; [312] 6.173; [313] 6.174; [314] 6.175; [315] 6.175; [316] 6. ...

# %%
freqs[i]/1e9
# Out:
# 6.8e-09

# %%
"""Plot (and get) a specific measure AND Fit"""
sma_freq_index = 150
print("SMA freq [GHz]: ", freqs[sma_freq_index])


group = "/SMA_power"+str(sma_pow)+"dBm/"

fmin = 4e9
fmax = 5e9

# Retrieve data from the specified dataset
datasets = getDatasets(filename,group,0)
hf = h5py.File(filename, 'r')
hfg = hf[group]
dataset_mat = hfg.get("drive_freq"+str(sma_freq_index))
f = dataset_mat[0]
I = dataset_mat[1]
Q = dataset_mat[2]
hf.close()

S21dB = 20*np.log10(np.sqrt(np.multiply(I,I)+np.multiply(Q,Q)))
plt.plot(f,S21dB)
"drive_freq"+str(sma_freq_index)
# Out:
# SMA freq [GHz]:  6.0277970813064625
# 'drive_freq50'

# %%
"""GAIN AVERAGE"""
sma_pow = -40
print("SMA freq [GHz]: ", freqs[sma_freq_index])


group = "/SMA_power"+str(sma_pow)+"dBm/"

fmin = 4e9
fmax = 5e9

# Retrieve data from the specified dataset
datasets = getDatasets(filename,group,0)
hf = h5py.File(filename, 'r')
hfg = hf[group]
gain_average = np.zeros(n_freq)
for i in np.arange(0,n_freq):
    dataset_mat = hfg.get("drive_freq"+str(i))
    f = dataset_mat[0]
    I = dataset_mat[1]
    Q = dataset_mat[2]
    S21dB = 20*np.log10(np.sqrt(np.multiply(I,I)+np.multiply(Q,Q)))
    #gain_average[i] = np.mean(S21dB)
    phase = np.arctan2(Q,I)
    gain_average[i] = S21dB[200]
hf.close()


plt.plot(freqs,gain_average)
#"drive_freq"+str(sma_freq_index)
# Out:
# SMA freq [GHz]:  6.7894371091035435

# %%
datasets = getDatasets(filename,group,0)
hf = h5py.File(filename, 'r')
hfg = hf[group]
dataset_mat = hfg.get("drive_freq"+str(799))
f = dataset_mat[0]
I = dataset_mat[1]
Q = dataset_mat[2]
S21dB = 20*np.log10(np.sqrt(np.multiply(I,I)+np.multiply(Q,Q)))
plt.plot(S21dB)

# %%
# Add the simulation parameters in title (of the above plot)
title = original_title
title = title + "\n" + "Pump frequency: " + str(round(freqs[pump_freq_index], freq_cifers)) + " GHz"
title = title + "\n" + "Bias current: " + str(round(volts[dc_volt_index]/R*1e3, volt_cifers)) + " mA"
title = title + "\n" + "Pump power: " + str(round(ampls[pump_pow_index], ampl_cifers)) + "dBm"
ax.set_title(title)
fig

# %%
"""Check Bias and Pump OFF pre and after"""

fig, ax = plt.subplots()
xs, yoff1 = getDatasetValue(filename,"Off",0)
xs, yoff2 = getDatasetValue(filename,"Off_4",0)
ax.plot(xs[100:220]/1e9,yoff2[100:220]-yoff1[100:220])
ax.set_title("Difference between ALL OFF measurements\ntaken at the beginning and at the end")
ax.set_xlabel("frequency [GHz]")
ax.set_ylabel("gain [dBm]")

# %% [markdown]
# NOTE!: Both 'Off' measurement and 'On' measurements need to be present in the SAME .h5 file and must be taken adopting the same parameters for the VNA!

# %% [markdown]
# - Consider many selected measurements (all the ones associated to the chosen parameters)
# - Subtract the 'Off' measure
# - Plot all those measurements on the same canvas in the desired span [ fmin,fmax ]

# %%
"""Gain of some selected experiments"""
voltage_indexes = [5]
frequency_indexes = [0]
power_indexes = [14]

fmin = 5e9 #[GHz]
fmax = 8e9 #[GHz]
fspan = fmax - fmin


fig, ax = plt.subplots()
# Get 'Off' measurement (will be subtracted to all measurements)
xoff, yoff = getDatasetValue(filename, "/Off", 0)
# Check if the frequency span [fmin,fmax] is valid
if xoff[0] <= fmin and xoff[len(xoff)-1] >= fmax:
    print("Band: [",round(fmin/1e9,freq_cifers),", ",round(fmax/1e9,freq_cifers),"] GHz")
else:
    print("Invalid frequency span!")
    exit()
# Get i_min, i_max for the defined band
df = xoff[1] - xoff[0]
i_min = round((fmin - xoff[0])/df)
i_max = round(len(xoff) - 1 - (xoff[len(xoff)-1] - fmax)/df)
n_pts = i_max - i_min

for k in voltage_indexes:
    for j in power_indexes:
        for i in frequency_indexes:
            # Get desired dataset
            group = "/dc_" + str(k) + "/pumpfreq_" + str(i) + "/pumppow_" + str(j)
            print(group)
            temp_xs, temp_ys = getDatasetValue(filename, group, 0)
            # Remove the 'Off' measurement
            temp_ys = temp_ys - yoff

            # Focus on the defined BAND
            xs = temp_xs[i_min:i_max]
            ys = temp_ys[i_min:i_max]

            # Plot S21 in the desired Fspan and get 'gain band average'
            ax.plot(xs/1e9,ys,label=(str(round(volts[k],volt_cifers))+"V,"+str(round(ampls[j],ampl_cifers))+"dBm,"+str(round(freqs[i],freq_cifers))+"GHz, pts"+str(n_pts)))

            """FIT"""
            z = np.polyfit(xs/1e9, ys, 1)
            ax.plot(xs/1e9,z[1]+z[0]*xs/1e9)

ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.grid()
ax.set_xlabel("Signal frequency [GHz]")
ax.set_ylabel("S21")
ax.set_title("Paramp gain\n['Off' measurement subtracted]")

# %% [markdown]
# Find optimal parameters among *ALL* the measurements in the .h5 file

# %%
"""BEST PARAMETERS"""

fmin = 8e9 #[GHz]
fmax = 11e9 #[GHz]
fspan = fmax - fmin


# Get 'Off' measurement (will be subtracted to all measurements)
xoff, yoff = getDatasetValue(filename, "/Off", 0)
#group = "/dc_" + "0" + "/pumpfreq_" + "0" + "/pumppow_" + "0"
#xoff, yoff = getDatasetValue(filename, group, 0)
#yoff = np.zeros(len(yoff))

# Check if the frequency span [fmin,fmax] is valid
if xoff[0] <= fmin and xoff[len(xoff)-1] >= fmax:
    print("Band: [",round(fmin/1e9,freq_cifers),", ",round(fmax/1e9,freq_cifers),"] GHz")
else:
    sys.exit("Invalid frequency span!")
# Get i_min, i_max for the defined band
df = xoff[1] - xoff[0]
i_min = round((fmin - xoff[0])/df)
i_max = round(len(xoff) - 1 - (xoff[len(xoff)-1] - fmax)/df)
n_pts = i_max - i_min

band_averages = np.zeros((len(volts),len(freqs),len(ampls)))
band_std = np.zeros((len(volts),len(freqs),len(ampls)))
band_slope = np.zeros((len(volts),len(freqs),len(ampls)))
band_slope_err = np.zeros((len(volts),len(freqs),len(ampls)))
max_average = [0,0,0]    # Indexes of params for best band average
for k in np.arange(0,len(volts)):
    for j in np.arange(0,len(ampls)):
        for i in np.arange(0,len(freqs)):
            # Get desired dataset
            group = "/dc_" + str(k) + "/pumpfreq_" + str(i) + "/pumppow_" + str(j)
            try:
                temp_xs, temp_ys = getDatasetValue(filename, group, 0)
                # Remove the 'Off' measurement
                temp_ys = temp_ys - yoff
                # Focus on the defined BAND
                xs = temp_xs[i_min:i_max]
                ys = temp_ys[i_min:i_max]

                band_averages[k,i,j] = np.mean(ys)
                band_std[k,i,j] = np.std(ys)
                p, res, _, _, _ = np.polyfit(xs/1e9,ys,1,full=True)
                band_slope[k,i,j] = p[0]
                band_slope_err[k,i,j] = res/len(xs)
                if band_averages[max_average[0],max_average[1],max_average[2]] < band_averages[k,i,j]:
                    max_average = [k,i,j]
            except:
                print(volts[k],"   ",ampls[j])

# Get params for maximum band average
best_voltage = volts[max_average[0]]
best_freq = freqs[max_average[1]]
best_pow = ampls[max_average[2]]
print("Best params: ",best_voltage,"V, ",best_freq,"GHz, ",best_pow,"dBm")
print("Best Band average gain: ",round(band_averages[max_average[0],max_average[1],max_average[2]],3),"dBm")

# Plot band average varying only Pump frequency (other two params fixed at 'optimal' values)
fig_freq, ax_freq = plt.subplots()
ax_freq.plot(freqs, band_averages[max_average[0],:,max_average[2]],'.-')
ax_freq.set_title("Band average ["+str(round(fmin/1e9,freq_cifers))+", "+str(round(fmax/1e9,freq_cifers))+"] GHz\nBias: "+str(round(best_voltage,volt_cifers))+"V; Pump Pow: "+str(round(best_pow,ampl_cifers))+"dBm")
ax_freq.set_xlabel("Pump frequency [GHz]")
ax_freq.set_ylabel("Averaged gain [dB]")

# Plot band average varying only Pump power (other two params fixed at 'optimal' values)
fig_pow, ax_pow = plt.subplots()
ax_pow.plot(ampls, band_averages[max_average[0],max_average[1],:],'.-')
ax_pow.set_title("Band average ["+str(round(fmin/1e9,freq_cifers))+", "+str(round(fmax/1e9,freq_cifers))+"] GHz\nBias: "+str(round(best_voltage,volt_cifers))+"V; Pump Freq: "+str(round(best_freq,freq_cifers))+"GHz")
ax_pow.set_xlabel("Pump power [dBm]")
ax_pow.set_ylabel("Averaged gain [dB]")

# Plot band average varying only Bias voltage (other two params fixed at 'optimal' values)
fig_freq, ax_freq = plt.subplots()
ax_freq.plot(volts, band_averages[:,max_average[1],max_average[2]],'.-')
ax_freq.set_title("Band average ["+str(round(fmin/1e9,freq_cifers))+", "+str(round(fmax/1e9,freq_cifers))+"] GHz\nPump Freq: "+str(round(best_freq,freq_cifers))+"GHz; Pump Pow: "+str(round(best_pow,ampl_cifers))+"dBm")
ax_freq.set_xlabel("Bias voltage [V]")
ax_freq.set_ylabel("Averaged gain [dB]")

# %%
"""3D PLOT"""
from mpl_toolkits.mplot3d import Axes3D


best_gain = round(band_averages[max_average[0],max_average[1],max_average[2]],3)
# In order to have a more precise colormap, we exclude values less than a
# selected one, assigning them to this selected value
minimum_plot_gain = 3 #[dBm]


B, D = np.meshgrid(ampls, volts)
average = np.zeros((len(ampls),len(volts)))
std = np.zeros((len(ampls),len(volts)))
slope = np.zeros((len(ampls),len(volts)))
slope_err = np.zeros((len(ampls),len(volts)))
for x in np.arange(0,len(ampls)):
    for y in np.arange(0,len(volts)):
        if band_averages[y,0,x] < minimum_plot_gain:
            average[x,y] = minimum_plot_gain
        else:
            average[x,y] = band_averages[y,0,x]
        std[x,y] = abs(band_std[y,0,x]/band_averages[y,0,x])
        slope[x,y] = abs(band_slope[y,0,x])
        slope_err[x,y] = abs(band_slope_err[y,0,x])

D = D/R*1e3 # Voltage [V] to current [mA]
fig = plt.figure()
plt.pcolor(D, B, np.transpose(average), vmin=minimum_plot_gain, vmax=best_gain)
plt.colorbar()
plt.ylabel('Pump Power [dBm]')
plt.xlabel('DC current [mA]')
plt.title('Average Gain [dBm] in [5,8]GHz\nf_pump = 15.722 GHz')
plt.show()

fig2 = plt.figure()
plt.pcolor(D, B, np.transpose(slope), vmax=2)
plt.colorbar()
plt.ylabel('Pump Power [dBm]')
plt.xlabel('DC current [mA]')
plt.title('Band Slope in [5,8]GHz\nf_pump = 15.722 GHz')
plt.show()

fig3 = plt.figure()
plt.pcolor(D, B, np.transpose(slope_err),vmax=3)
plt.colorbar()
plt.ylabel('Pump Power [dBm]')
plt.xlabel('DC current [mA]')
plt.title('Band Slope Fit error in [5,8]GHz\nf_pump = 15.722 GHz')
plt.show()

fig4 = plt.figure()
plt.pcolor(D, B, np.transpose(std),vmin=0,vmax=0.5)
plt.colorbar()
plt.ylabel('Pump Power [dBm]')
plt.xlabel('DC current [mA]')
plt.title('Gain Std/Average in [5,8]GHz\nf_pump = 15.722 GHz')
plt.show()

# %%
"""DELETE a dataset"""
full_dataset_path = "/group/dataset_to_delete"
deleteDataset(filename, full_dataset_path)

# %%
"""Save a dataset"""
filename_save = "save.h5"
full_dataset_path = "/group/datasetname"

mat = [xs1, ys1]
hf = h5py.File(filename_save, 'a')
hf.create_dataset(full_dataset_path, data = mat)
hf.close()
